# %% [markdown]
# Write a program that asks the user for their name and age, then displays a greeting including both pieces of information.

# %%
name = input("Enter your name: ")
age = input("Enter your age: ")
print(f"Hi {name}, nice to know that you're {age} years of age.")

# %%
file_h= open("mine.txt","w")
file_h.write("George Smith")
file_h.close()

# %%
file_h= open("mine.txt","a")
file_h.write("Rivers")
file_h.close()

# %%
file_h= open("mine.txt","a")
file_h.write("\nMarried")
file_h.close()
