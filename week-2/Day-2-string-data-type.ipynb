# %% [markdown]
# # String Data type

# %%
a= 20
b=4.6
c=3+7j
d="20"
e=False

# %%
type(a)
# Out:
# int

# %%
type(d)
# Out:
# str

# %%
type(c)
# Out:
# complex

# %%
first_name ="Boma"
last_name ='George'
other_name ="""Smith"""
country ='''Nigeria'''

# %%
first_name
# Out:
# 'Boma'

# %%
last_name
# Out:
# 'George'

# %%
other_name
# Out:
# 'Smith'

# %%
test="This is me.
I will cme for you"
# Out:
#   Cell In[11], line 1
#     test="This is me.
#          ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
test="""This is me.
I will cme for you"""

# %%
print(test)
# Out:
# This is me.
# I will cme for you

# %%
stm ="He said  "I will come for you""
# Out:
#   Cell In[15], line 1
#     stm ="He said  "I will come for you""
#                     ^
# SyntaxError: invalid syntax

# %%
stm ="He said  'I will come for you'"

# %%
stm
# Out:
# "He said  'I will come for you'"

# %%
stm ='He said  "I will come for you"'

# %%
stm
# Out:
# 'He said  "I will come for you"'

# %%
stm ="He said  \"I will come for you\""

# %%
stm
# Out:
# 'He said  "I will come for you"'

# %%
full_name= last_name+first_name

# %%
full_name
# Out:
# 'GeorgeBoma'

# %%
full_name= last_name+" "+first_name

# %%
full_name
# Out:
# 'George Boma'

# %%
sentence ="My name is "+last_name+" "+first_name+" and i like teaching"# concatenation

# %%
sentence
# Out:
# 'My name is George Boma and i like teaching'

# %%
sentence =f"My name is {last_name} {first_name} and i like teaching"# interpolation

# %%
sentence
# Out:
# 'My name is George Boma and i like teaching'

# %% [markdown]
# ## length of string

# %%
len(first_name)
# Out:
# 4

# %%
len(last_name)
# Out:
# 6

# %%
len("other_name")
# Out:
# 10

# %%
len(other_name)
# Out:
# 5

# %% [markdown]
# ## String indexing and slicing

# %%
first_name
# Out:
# 'Boma'

# %%
first_name[2]
# Out:
# 'm'

# %%
last_name[0]
# Out:
# 'G'

# %%
last_name[5]
# Out:
# 'e'

# %%
name = input("Enter your name: ")
last_char =name[len(name)-1]
print(last_char)
# Out:
# Enter your name:  Tinibu
# u

# %%
name = input("Enter your name: ")
last_char =name[-1]
print(last_char)
# Out:
# Enter your name:  Smith
# h

# %%
name = input("Enter your name: ")
result =name[0]+name[1]
print(result)
# Out:
# Enter your name:  dan
# da

# %%
last_name
# Out:
# 'George'

# %%
last_name[0:2:1]
# Out:
# 'Ge'

# %%
last_name[:2:]
# Out:
# 'Ge'

# %%
last_name[:2]
# Out:
# 'Ge'

# %%
last_name[0::2]
# Out:
# 'Gog'

# %%
last_name[::2]
# Out:
# 'Gog'

# %%
last_name[::-1]
# Out:
# 'egroeG'

# %% [markdown]
# ## String methods

# %%
last_name
# Out:
# 'George'

# %%
last_name.upper()
# Out:
# 'GEORGE'

# %%
last_name.lower()
# Out:
# 'george'

# %%
last_name.find("e")
# Out:
# 1

# %%
last_name.find("j")
# Out:
# -1

# %%
last_name.

# %%
sentence
# Out:
# 'My name is George Boma and i like teaching'

# %%
sentence.capitalize()
# Out:
# 'My name is george boma and i like teaching'

# %%
sentence.title()
# Out:
# 'My Name Is George Boma And I Like Teaching'

# %%
last_name.startswith("g")
# Out:
# False

# %%
last_name.startswith("Ge")
# Out:
# True

# %%
last_name.split("o")
# Out:
# ['Ge', 'rge']

# %%
last_name.split("e")
# Out:
# ['G', 'org', '']

# %%
last_name.
