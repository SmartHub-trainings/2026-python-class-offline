# %%
a=20
b=40
c=a+b
print(c)
# Out:
# 60

# %%
a=20;
b=40;
c=a+b;
print(c);
# Out:
# 60

# %%
a=20; b=40; c=a+b;print(c)
# Out:
# 60

# %% [markdown]
# # input statements

# %%
a=56
b=10
c=a+b
print(c)
# Out:
# 66

# %%
a=input()
b=input()
c=a+b
print(c)
# Out:
#  2
#  5
# 25

# %%
a=input()
b=input()
c=float(a)+float(b)
print(c)
# Out:
#  2
#  5
# 7.0

# %%
a=input("Enter the value of a: ")
b=input("Enter the value of b: ")
c=float(a)+float(b)
print(c)
# Out:
# Enter the value of a:  5
# Enter the value of b:  8
# 13.0

# %%
a=float(input("Enter the value of a: "))
b=float(input("Enter the value of b: "))
c=a+b
print("The sum of the numbers is","c")
# Out:
# Enter the value of a:  4
# Enter the value of b:  7
# The sum of the numbers is c

# %%
print(5,60,20)
# Out:
# 5 60 20

# %%
a=float(input("Enter the value of a: "))
b=float(input("Enter the value of b: "))
c=a+b
print("The sum of the numbers is",c)
# Out:
# Enter the value of a:  20
# Enter the value of b:  56
# The sum of the numbers is 76.0

# %%
a=float(input("Enter the value of a: "))
b=float(input("Enter the value of b: "))
c=a+b
print("The sum of",a,"and",b,"is",c)
# Out:
# Enter the value of a:  5
# Enter the value of b:  20
# The sum of 5.0 and 20.0 is 25.0

# %%
name = input("Enter your name: ")
age = input("Enter your age: " )
print("name is age years old.")
# Out:
# Enter your name:  Smith
# Enter your age:  26
# name is age years old.

# %%
name = input("Enter your name: ")
age = input("Enter your age: " )
print(name, "is", age, "years old.")
# Out:
# Enter your name:  smith
# Enter your age:  89
# smith is 89 years old.

# %%
a=float(input("Enter the value of a: "))
b=float(input("Enter the value of b: "))
c=a+b
print("The sum of a and b is c")
# Out:
# Enter the value of a:  23
# Enter the value of b:  45
# The sum of a and b is c

# %%
a=float(input("Enter the value of a: "))
b=float(input("Enter the value of b: "))
c=a+b
print("The sum of {a} and {b} is {c}")
# Out:
# Enter the value of a:  23
# Enter the value of b:  4
# The sum of {a} and {b} is {c}

# %%
a=float(input("Enter the value of a: "))
b=float(input("Enter the value of b: "))
c=a+b
print(f"The sum of {a} and {b} is {c}")
# Out:
# Enter the value of a:  12
# Enter the value of b:  45
# The sum of 12.0 and 45.0 is 57.0

# %%
name = input("Enter your name: ")
age = input("Enter your age: " )
print(f"{name} is {age} years old.")# string interpolation
# Out:
# Enter your name:  Smith
# Enter your age:  78
# Smith is 78 years old.
