# %%
is_saturday =True
web_class_held=False

# %%
2>5
# Out:
# False

# %%
10>=7
# Out:
# True

# %%
10>7
# Out:
# True

# %%
"Data"=="data"
# Out:
# False

# %%
"Data">"data"
# Out:
# False

# %%
"data">"Data"
# Out:
# True

# %%
2>5 and 7<5
# Out:
# False

# %%
90>=12 or is_saturday==False
# Out:
# True

# %%
is_saturday==False
# Out:
# False

# %%
# False  is seen as 0
# True is seen as 1.

# %%
True +20
# Out:
# 21

# %%
False*100
# Out:
# 0

# %%
True *30
# Out:
# 30

# %% [markdown]
# ## Truthy and Falsy values

# %%
bool(30)
# Out:
# True

# %%
bool(-1000)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
# All numbers are truthy except 0

# %%
bool("Smith")
# Out:
# True

# %%
bool("")
# Out:
# False

# %%
bool(" ")
# Out:
# True

# %% [markdown]
# ## short circuiting

# %% [markdown]
# in a series of statement, where the logical operator is a "and" or "or"
# for
# * Or, the statement that is more likeley to be True should come first
# * and , the statement that is more likely to be False should come first

# %% [markdown]
# ## Conditional Control structure

# %%
# one form of contrl structure is 

# if conditions:
#     do_something

# %%
number = float(input("Enter a number: "))
if number >10:
    print("Great. The number is more than 10.")
# Out:
# Enter a number:  8
