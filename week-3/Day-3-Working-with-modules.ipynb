# %%
pi
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 pi
#
# NameError: name 'pi' is not defined

# %%
factorial(3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 factorial(3)
#
# NameError: name 'factorial' is not defined

# %%
# general import
import math

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.factorial(3)
# Out:
# 6

# %%
pi
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 pi
#
# NameError: name 'pi' is not defined

# %%
# Specific import 
from math import pi,factorial

# %%
pi
# Out:
# 3.141592653589793

# %%
factorial(4)
# Out:
# 24

# %%
dir(math)
# Out:
# ['__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'cbrt',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'exp2',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fma',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'lcm',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'nextafter',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'sumprod',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc',
#  'ulp']

# %%
import math as mine

# %%
mine.pi
# Out:
# 3.141592653589793

# %%
mine.e
# Out:
# 2.718281828459045

# %%
mine.sin(75)
# Out:
# -0.38778163540943045

# %%
dir()
# Out:
# ['In',
#  'Out',
#  '_',
#  '_10',
#  '_11',
#  '_12',
#  '_13',
#  '_14',
#  '_15',
#  '_2',
#  '_3',
#  '_4',
#  '_5',
#  '_6',
#  '_7',
#  '_8',
#  '_9',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__pandas',
#  '__session__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i10',
#  '_i11',
#  '_i12',
#  '_i13',
#  '_i14',
#  '_i15',
#  '_i2',
#  '_i3',
#  '_i4',
#  '_i5',
#  '_i6',
#  '_i7',
#  '_i8',
#  '_i9',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'dataframe_columns',
#  'dataframe_hash',
#  'dtypes_str',
#  'exit',
#  'factorial',
#  'get_dataframes',
#  'get_ipython',
#  'getpass',
#  'hashlib',
#  'import_pandas_safely',
#  'is_data_frame',
#  'json',
#  'math',
#  'mine',
#  'open',
#  'pi',
#  'quit']

# %%
from math import *

# %%
dir()
# Out:
# ['In',
#  'Out',
#  '_',
#  '_10',
#  '_11',
#  '_12',
#  '_13',
#  '_14',
#  '_15',
#  '_16',
#  '_17',
#  '_2',
#  '_3',
#  '_4',
#  '_5',
#  '_6',
#  '_7',
#  '_8',
#  '_9',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__pandas',
#  '__session__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i10',
#  '_i11',
#  '_i12',
#  '_i13',
#  '_i14',
#  '_i15',
#  '_i16',
#  '_i17',
#  '_i2',
#  '_i3',
#  '_i4',
#  '_i5',
#  '_i6',
#  '_i7',
#  '_i8',
#  '_i9',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'cbrt',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'dataframe_columns',
#  'dataframe_hash',
#  'degrees',
#  'dist',
#  'dtypes_str',
#  'e',
#  'erf',
#  'erfc',
#  'exit',
#  'exp',
#  'exp2',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fma',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
# ...

# %%
pi
# Out:
# 3.141592653589793

# %%
sin(67)
# Out:
# -0.8555199789753223

# %%
cos(782)
# Out:
# -0.967265889198305

# %%
import random

# %%
dir(random)
# Out:
# ['BPF',
#  'LOG4',
#  'NV_MAGICCONST',
#  'RECIP_BPF',
#  'Random',
#  'SG_MAGICCONST',
#  'SystemRandom',
#  'TWOPI',
#  '_ONE',
#  '_Sequence',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_accumulate',
#  '_acos',
#  '_bisect',
#  '_ceil',
#  '_cos',
#  '_e',
#  '_exp',
#  '_fabs',
#  '_floor',
#  '_index',
#  '_inst',
#  '_isfinite',
#  '_lgamma',
#  '_log',
#  '_log2',
#  '_os',
#  '_parse_args',
#  '_pi',
#  '_random',
#  '_repeat',
#  '_sha512',
#  '_sin',
#  '_sqrt',
#  '_test',
#  '_test_generator',
#  '_urandom',
#  'betavariate',
#  'binomialvariate',
#  'choice',
#  'choices',
#  'expovariate',
#  'gammavariate',
#  'gauss',
#  'getrandbits',
#  'getstate',
#  'lognormvariate',
#  'main',
#  'normalvariate',
#  'paretovariate',
#  'randbytes',
#  'randint',
#  'random',
#  'randrange',
#  'sample',
#  'seed',
#  'setstate',
#  'shuffle',
#  'triangular',
#  'uniform',
# ...

# %%
from random import choice, choices, randint

# %%
randint(2,20)
# Out:
# 8

# %%
choice([4,5,7,9])
# Out:
# 5

# %%
choice(["Rock","Papper","scissors"])
# Out:
# 'Papper'

# %%
choices(["Rock","Papper","scissors"])
# Out:
# ['scissors']

# %%
choices(["Rock","Papper","scissors"],k=2)
# Out:
# ['Papper', 'Papper']

# %%
## Guessing game (Version 2)
magic_number = randint(2,7)
# print(magic_number)
for i in range(5):
    user_guess = int(input("Guess the magic number(2-7): "))
    if user_guess==magic_number:
        print("You're Good!!")
    else:
        print("Think for once!!\nTry again")
# Out:
# Guess the magic number(2-7):  8
# Think for once!!
# Try again
# Guess the magic number(2-7):  6
# Think for once!!
# Try again
# Guess the magic number(2-7):  3
# You're Good!!
# Guess the magic number(2-7):  5
# Think for once!!
# Try again
# Guess the magic number(2-7):  6
# Think for once!!
# Try again

# %%
## Guessing game (Version 2)
magic_number = randint(2,7)
# print(magic_number)
for i in range(5):
    user_guess = int(input("Guess the magic number(2-7): "))
    if user_guess==magic_number:
        print("You're Good!!")
        break
    else:
        print("Think for once!!\nTry again")
# Out:
# Guess the magic number(2-7):  6
# Think for once!!
# Try again
# Guess the magic number(2-7):  6
# Think for once!!
# Try again
# Guess the magic number(2-7):  6
# Think for once!!
# Try again
# Guess the magic number(2-7):  6
# Think for once!!
# Try again
# Guess the magic number(2-7):  6
# Think for once!!
# Try again

# %%
## Guessing game (Version 2)
magic_number = randint(2,7)
# print(magic_number)
for i in range(5):
    user_guess = int(input("Guess the magic number(2-7): "))
    if user_guess==magic_number:
        print("You're Good!!")
        break
    elif i <4:
            print("Think for once!!\nTry again")
    else:
        print("Game Over!!")
# Out:
# Guess the magic number(2-7):  7
# Think for once!!
# Try again
# Guess the magic number(2-7):  7
# Think for once!!
# Try again
# Guess the magic number(2-7):  7
# Think for once!!
# Try again
# Guess the magic number(2-7):  7
# Think for once!!
# Try again
# Guess the magic number(2-7):  7
# Game Over!!
