# %%
my_file = open("scores.txt","r")
content=my_file.read()
print(content)
# Out:
# 2
# 4
# 5
# 4
# 6
# 4
# 78
# 34
# 23
# 56
# 78
# 23
# 90
# 12

# %%
my_file = open("scores.txt","r")
content=my_file.read()
content
# Out:
# '2\n4\n5\n4\n6\n4\n78\n34\n23\n56\n78\n23\n90\n12'

# %%
my_file = open("scores.txt","r")
content=my_file.readlines()
content
# Out:
# ['2\n',
#  '4\n',
#  '5\n',
#  '4\n',
#  '6\n',
#  '4\n',
#  '78\n',
#  '34\n',
#  '23\n',
#  '56\n',
#  '78\n',
#  '23\n',
#  '90\n',
#  '12']

# %%
my_file = open("scores.txt","r")
content=my_file.readlines()
content[:4]
# Out:
# ['20\n', '40\n', '57\n', '47\n']

# %%
my_file = open("scores.txt","r")
content=my_file.readlines()
# print(content)
for item in content:
    score = int(item.strip())
    print(score)
    if score >=70:
        print("A")
    elif score >=60:
        print("B")
    elif score >= 50:
        print("C")
    elif score >=45:
        print("D")
    elif score >= 40:
        print("E")
    else:
        print("F")
    print()
# Out:
# 20
# F
#
# 40
# E
#
# 57
# C
#
# 47
# D
#
# 65
# B
#
# 49
# D
#
# 78
# A
#
# 34
# F
#
# 23
# F
#
# 56
# C
#
# 78
# A
#
# 23
# F
#
# 90
# A
#
# 12
# F

# %%
"dbfjhdbfjh    \n".strip()
# Out:
# 'dbfjhdbfjh'

# %%
my_file = open("scores.txt","r")
content=my_file.readlines()
output_file = open("mod_scores.txt","w")
# print(content)
for item in content:
    score = int(item.strip())
    print(score)
    if score >=70:
        grade="A"
    elif score >=60:
        grade="B"
    elif score >= 50:
        grade="C"
    elif score >=45:
        grade="D"
    elif score >= 40:
        grade="E"
    else:
        grade="F"
    output_file.write(f"score: {score},grade: {grade}\n")
output_file.close()
# Out:
# 20
# 40
# 57
# 47
# 65
# 49
# 78
# 34
# 23
# 56
# 78
# 23
# 90
# 12

# %% [markdown]
# In a particular jurisdiction, older license plates consist of three uppercase letters
# followed by three numbers. When all of the license plates following that pattern had
# been used, the format was changed to four numbers followed by three uppercase
# letters.
# Write a program that begins by reading a string of characters from the user. Then
# your program should display a message indicating whether the characters are valid
# for an older style license plate or a newer style license plate. Your program should
# display an appropriate message if the string entered by the user is not valid for either
# style of license plate.

# %%
plate_number = input("Enter the plate number: ")
# old plate style 
if (len(plate_number)==6 
    and plate_number[:3].isalpha() 
    and plate_number[3:].isnumeric()
    and plate_number[:3].isupper()
   ):
    print("The license plate number is a valid(old styled) plate number")
# Out:
# Enter the plate number:  MNr783

# %%
plate_number = input("Enter the plate number: ")
# old plate style 
# if len(plate_number)>7 or len(plate_number)<6:
if len(plate_number) not in [6,7]:
    print("This is an invalid plate number")
elif (len(plate_number)==6 
    and plate_number[:3].isalpha() 
    and plate_number[3:].isnumeric()
    and plate_number[:3].isupper()
   ):
    print("The license plate number is a valid(old styled) plate number")
